# %%
# -*- coding: utf-8 -*-

import datetime

i = 0
convertString = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ"



# --- def ---
# --- 遞迴 ---
def convD(n,b):
 
    if n < b:
        return convertString[n]
    else:
        return convD(n//b,b) + convertString[n%b]


# --- 迴圈 ---
def convH(n,b):
    
    q = ''

    while n > 0:
        if n >= b:
            q += convertString[n%b]
            n = n // b
        
            #print("n = ",n)
            #print("q = ",q)
        elif n // b < b:
            q += convertString[n%b]
            #print(q)
            r = list(q)
            r.reverse()
            a = ''.join(r)
            return a
        else:
            return 0
    


# --- Loop for 5 inputs & results ---
while i < 5:
    
    i += 1
    print("第",i,"筆資料")
    
    n = int(input("請輸入十進制正整數: "))
    b = int(input("請輸入欲轉換進制: "))
    
    
    tStartD = datetime.datetime.now()
    print(n,"(10) ->",convD(n,b),"(",b,")")
    tEndD = datetime.datetime.now()
    print("遞迴轉換運行時間: ",tEndD - tStartD, "\n")

    tStartH = datetime.datetime.now()
    print(n,"(10) ->",convH(n,b),"(",b,")")
    tEndH = datetime.datetime.now()
    print("迴圈轉換運行時間: ",tEndH - tStartH, "\n")
# Out:
# 第 1 筆資料
# 請輸入十進制正整數: 123456
# 請輸入欲轉換進制: 32
# 123456 (10) -> 3OI0 ( 32 )
# 遞迴轉換運行時間:  0:00:00.000269
#
# 123456 (10) -> 3OI0 ( 32 )
# 迴圈轉換運行時間:  0:00:00.000310
#
# 第 2 筆資料
# 請輸入十進制正整數: 123321
# 請輸入欲轉換進制: 18
# 123321 (10) -> 132B3 ( 18 )
# 遞迴轉換運行時間:  0:00:00.000310
#
# 123321 (10) -> 132B3 ( 18 )
# 迴圈轉換運行時間:  0:00:00.000466
#
# 第 3 筆資料
# 請輸入十進制正整數: 138786
# 請輸入欲轉換進制: 19
# 138786 (10) -> 1148A ( 19 )
# 遞迴轉換運行時間:  0:00:00.000405
#
# 138786 (10) -> 1148A ( 19 )
# 迴圈轉換運行時間:  0:00:00.000240
#
# 第 4 筆資料
# 請輸入十進制正整數: 127391728
# 請輸入欲轉換進制: 25
# 127391728 (10) -> D131J3 ( 25 )
# 遞迴轉換運行時間:  0:00:00.000441
#
# 127391728 (10) -> D131J3 ( 25 )
# 迴圈轉換運行時間:  0:00:00.000325
#
# 第 5 筆資料
# 請輸入十進制正整數: 192309809
# 請輸入欲轉換進制: 30
# 192309809 (10) -> 7RCHGT ( 30 )
# 遞迴轉換運行時間:  0:00:00.000452
#
# 192309809 (10) -> 7RCHGT ( 30 )
# 迴圈轉換運行時間:  0:00:00.000298
